# %%
import pandas as pd 

df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
print(df.shape)
df.head()
# Out:
# (891, 12)
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# ...

# %%
df.dropna(axis = 0)  # removing drop na
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.dropna(axis=1,thresh=800,inplace=True)

# %%
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       2
# dtype: int64

# %%
# df.fillna()

# %%
df.groupby('Survived').describe().T
# Out:
# Survived                    0           1
# PassengerId count  549.000000  342.000000
#             mean   447.016393  444.368421
#             std    260.640469  252.358840
#             min      1.000000    2.000000
#             25%    211.000000  250.750000
#             50%    455.000000  439.500000
#             75%    675.000000  651.500000
#             max    891.000000  890.000000
# Pclass      count  549.000000  342.000000
#             mean     2.531876    1.950292
#             std      0.735805    0.863321
#             min      1.000000    1.000000
#             25%      2.000000    1.000000
#             50%      3.000000    2.000000
#             75%      3.000000    3.000000
#             max      3.000000    3.000000
# SibSp       count  549.000000  342.000000
#             mean     0.553734    0.473684
#             std      1.288399    0.708688
#             min      0.000000    0.000000
#             25%      0.000000    0.000000
# ...

# %%
df = pd.read_csv("bank.csv",sep=";")
df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   30   unemployed  married    primary      no     1787      no   no
# 1   33     services  married  secondary      no     4789     yes  yes
# 2   35   management   single   tertiary      no     1350     yes   no
# 3   30   management  married   tertiary      no     1476     yes  yes
# 4   59  blue-collar  married  secondary      no        0     yes   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   19   oct        79         1     -1         0  unknown  no
# 1  cellular   11   may       220         1    339         4  failure  no
# 2  cellular   16   apr       185         1    330         1  failure  no
# 3   unknown    3   jun       199         4     -1         0  unknown  no
# 4   unknown    5   may       226         1     -1         0  unknown  no

# %%
df1 = []
for i in df['education'].unique():
    df1.append(pd.DataFrame(df[df['education'] == i]))

# %%
primary = df1[0]
secondary = df1[1]

# %%
primary
# Out:
#       age            job   marital education default  balance housing loan  \
# 0      30     unemployed   married   primary      no     1787      no   no
# 9      43       services   married   primary      no      -88     yes  yes
# 18     25    blue-collar    single   primary      no     -221     yes   no
# 26     55    blue-collar   married   primary      no      627     yes   no
# 36     78        retired  divorced   primary      no      229      no   no
# ...   ...            ...       ...       ...     ...      ...     ...  ...
# 4480   23    blue-collar   married   primary      no     1158     yes   no
# 4485   53    blue-collar   married   primary      no      238     yes   no
# 4486   37    blue-collar   married   primary      no      378     yes   no
# 4499   45    blue-collar  divorced   primary      no      942      no   no
# 4503   60  self-employed   married   primary      no      362      no  yes
#
# ...

# %%
secondary
# Out:
#       age          job  marital  education default  balance housing loan  \
# 1      33     services  married  secondary      no     4789     yes  yes
# 4      59  blue-collar  married  secondary      no        0     yes   no
# 7      39   technician  married  secondary      no      147     yes   no
# 10     39     services  married  secondary      no     9374     yes   no
# 11     43       admin.  married  secondary      no      264     yes   no
# ...   ...          ...      ...        ...     ...      ...     ...  ...
# 4514   38  blue-collar  married  secondary      no     1205     yes   no
# 4515   32     services   single  secondary      no      473     yes   no
# 4516   33     services  married  secondary      no     -333     yes   no
# 4518   57   technician  married  secondary      no      295      no   no
# 4519   28  blue-collar  married  secondary      no     1137      no   no
#
#        contact  day month  duration  campaign  pdays  previous poutcome   y
# ...

# %%
pd.concat([primary,secondary]) #
# Out:
#       age          job   marital  education default  balance housing loan  \
# 0      30   unemployed   married    primary      no     1787      no   no
# 9      43     services   married    primary      no      -88     yes  yes
# 18     25  blue-collar    single    primary      no     -221     yes   no
# 26     55  blue-collar   married    primary      no      627     yes   no
# 36     78      retired  divorced    primary      no      229      no   no
# ...   ...          ...       ...        ...     ...      ...     ...  ...
# 4514   38  blue-collar   married  secondary      no     1205     yes   no
# 4515   32     services    single  secondary      no      473     yes   no
# 4516   33     services   married  secondary      no     -333     yes   no
# 4518   57   technician   married  secondary      no      295      no   no
# 4519   28  blue-collar   married  secondary      no     1137      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# ...

# %%
df2 = primary.head()[['age', 'job', 'marital']]
df3 = secondary.head()[['age', 'job', 'marital']]

# %%
concat_df = pd.concat([df2,df3],axis=1)
concat_df
# Out:
#      age          job   marital   age          job  marital
# 0   30.0   unemployed   married   NaN          NaN      NaN
# 9   43.0     services   married   NaN          NaN      NaN
# 18  25.0  blue-collar    single   NaN          NaN      NaN
# 26  55.0  blue-collar   married   NaN          NaN      NaN
# 36  78.0      retired  divorced   NaN          NaN      NaN
# 1    NaN          NaN       NaN  33.0     services  married
# 4    NaN          NaN       NaN  59.0  blue-collar  married
# 7    NaN          NaN       NaN  39.0   technician  married
# 10   NaN          NaN       NaN  39.0     services  married
# 11   NaN          NaN       NaN  43.0       admin.  married

# %%
concat_df['age']
# Out:
#      age   age
# 0   30.0   NaN
# 9   43.0   NaN
# 18  25.0   NaN
# 26  55.0   NaN
# 36  78.0   NaN
# 1    NaN  33.0
# 4    NaN  59.0
# 7    NaN  39.0
# 10   NaN  39.0
# 11   NaN  43.0

# %%
#iloc takes inbuilt positional thing 
#Where loc takes  names rows and colouns

# %%
concat_df.iloc[:,3]
# Out:
# 0      NaN
# 9      NaN
# 18     NaN
# 26     NaN
# 36     NaN
# 1     33.0
# 4     59.0
# 7     39.0
# 10    39.0
# 11    43.0
# Name: age, dtype: float64

# %%
df2.loc[[9,18],['job','marital']]  # Named Ones
# Out:
#             job  marital
# 9      services  married
# 18  blue-collar   single

# %%
df2
# Out:
#     age          job   marital
# 0    30   unemployed   married
# 9    43     services   married
# 18   25  blue-collar    single
# 26   55  blue-collar   married
# 36   78      retired  divorced

# %%
df2.iloc[1:3,1:]
# Out:
#             job  marital
# 9      services  married
# 18  blue-collar   single

# %%
df2.iloc[1:3,2:]
# Out:
#     marital
# 9   married
# 18   single

# %%
# df.dropna(withparamsinsideparamsinplace,axis,thresh)
# fillna 
# Transpose
# groupby
# concat 
# loc
# iloc

# %%
# Merge

print(df2)
print(df3)

pd.merge(df2,df3,on='age')
# Out:
#     age          job   marital
# 0    30   unemployed   married
# 9    43     services   married
# 18   25  blue-collar    single
# 26   55  blue-collar   married
# 36   78      retired  divorced
#     age          job  marital
# 1    33     services  married
# 4    59  blue-collar  married
# 7    39   technician  married
# 10   39     services  married
# 11   43       admin.  married
#    age     job_x marital_x   job_y marital_y
# 0   43  services   married  admin.   married

# %%
pd.merge(df2,df3,on='age',how='right')
# Out:
#    age     job_x marital_x        job_y marital_y
# 0   33       NaN       NaN     services   married
# 1   59       NaN       NaN  blue-collar   married
# 2   39       NaN       NaN   technician   married
# 3   39       NaN       NaN     services   married
# 4   43  services   married       admin.   married

# %%
pd.merge(df2,df3,on='age',how='outer')
# Out:
#    age        job_x marital_x        job_y marital_y
# 0   30   unemployed   married          NaN       NaN
# 1   43     services   married       admin.   married
# 2   25  blue-collar    single          NaN       NaN
# 3   55  blue-collar   married          NaN       NaN
# 4   78      retired  divorced          NaN       NaN
# 5   33          NaN       NaN     services   married
# 6   59          NaN       NaN  blue-collar   married
# 7   39          NaN       NaN   technician   married
# 8   39          NaN       NaN     services   married

# %%
df2
# Out:
#     age          job   marital
# 0    30   unemployed   married
# 9    43     services   married
# 18   25  blue-collar    single
# 26   55  blue-collar   married
# 36   78      retired  divorced

# %%
# Join 

df2.join(df3,on='age',how='inner') # this will not work if we not select axis but merge not needed
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[84], line 3
#       1 # Join
# ----> 3 df2.join(df3,on='age',how='inner')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:9979, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#    9816 def join(
#    9817     self,
#    9818     other: DataFrame | Series | list[DataFrame | Series],
#    (...)
#    9824     validate: str | None = None,
#    9825 ) -> DataFrame:
#    9826     """
#    9827     Join columns of another DataFrame.
#    9828
#    (...)
#    9977     5  K1  A5   B1
#    9978     """
# -> 9979     return self._join_compat(
#    9980         other,
#    9981         on=on,
#    9982         how=how,
#    9983         lsuffix=lsuffix,
#    9984         rsuffix=rsuffix,
#    9985         sort=sort,
#    9986         validate=validate,
# ...

# %%
# like this 
df2 = df2.set_index('age')
df3=df3.set_index('age')

# %%
df3
# Out:
#              job  marital
# age
# 33      services  married
# 59   blue-collar  married
# 39    technician  married
# 39      services  married
# 43        admin.  married

# %%
# rename columns
df2.rename(columns = {'job':'job1','marital':'marital1'},inplace=True)

# %%
df3.join(df2,how='outer')
# Out:
#              job  marital         job1  marital1
# age
# 25           NaN      NaN  blue-collar    single
# 30           NaN      NaN   unemployed   married
# 33      services  married          NaN       NaN
# 39    technician  married          NaN       NaN
# 39      services  married          NaN       NaN
# 43        admin.  married     services   married
# 55           NaN      NaN  blue-collar   married
# 59   blue-collar  married          NaN       NaN
# 78           NaN      NaN      retired  divorced
