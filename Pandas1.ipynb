# %%
import pandas as pr

df = pr.read_csv('bank.csv',delimiter=";",skiprows=[1])

# %%
df.head()
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   33     services  married  secondary      no     4789     yes  yes
# 1   35   management   single   tertiary      no     1350     yes   no
# 2   30   management  married   tertiary      no     1476     yes  yes
# 3   59  blue-collar  married  secondary      no        0     yes   no
# 4   35   management   single   tertiary      no      747      no   no
#
#     contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  cellular   11   may       220         1    339         4  failure  no
# 1  cellular   16   apr       185         1    330         1  failure  no
# 2   unknown    3   jun       199         4     -1         0  unknown  no
# 3   unknown    5   may       226         1     -1         0  unknown  no
# 4  cellular   23   feb       141         2    176         3  failure  no

# %%
df.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# balance       int64
# housing      object
# loan         object
# contact      object
# day           int64
# month        object
# duration      int64
# campaign      int64
# pdays         int64
# previous      int64
# poutcome     object
# y            object
# dtype: object

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'y'],
#       dtype='object')

# %%
type(df[{'age'}])
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23128\703683407.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   type(df[{'age','job'}])
# pandas.core.frame.DataFrame

# %%
df[{'age','education'}]
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_23128\1485447074.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df[{'age','education'}]
#       age  education
# 0      33  secondary
# 1      35   tertiary
# 2      30   tertiary
# 3      59  secondary
# 4      35   tertiary
# ...   ...        ...
# 4515   33  secondary
# 4516   57   tertiary
# 4517   57  secondary
# 4518   28  secondary
# 4519   44   tertiary
#
# [4520 rows x 2 columns]

# %%
df = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
type(df[0])
# Out:
# pandas.core.frame.DataFrame

# %%
df[0].tail(3)
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST STL BLK TOV   PF  PTS
# 672  114  166   38  38   8  42   56  386
# 673  265  362  100  34  49  62  156  472
# 674  319  465  113  18  52  76  205  833
#
# [3 rows x 30 columns]

# %%
df[0].columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df[0].dtypes
# Out:
# Rk        object
# Player    object
# Pos       object
# Age       object
# Tm        object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# dtype: object

# %%
# Assassin's 
import pandas as pd 
df = pd.read_html("https://en.wikipedia.org/wiki/Assassin%27s_Creed")

# %%
df[1]['Game']
# Out:
# 0                    Assassin's Creed
# 1                 Assassin's Creed II
# 2       Assassin's Creed: Brotherhood
# 3       Assassin's Creed: Revelations
# 4                Assassin's Creed III
# 5     Assassin's Creed IV: Black Flag
# 6              Assassin's Creed Rogue
# 7              Assassin's Creed Unity
# 8          Assassin's Creed Syndicate
# 9            Assassin's Creed Origins
# 10           Assassin's Creed Odyssey
# 11          Assassin's Creed Valhalla
# Name: Game, dtype: object

# %%
import json
json1 = """{
   "name" : "prash",
    "email": "sub",
    "address":["XYZ","accc","sss"],
    "designation": ["Data Scientist","Devloper","Data Analyst"]
}"""

d1 = json.loads(json1)
d1
# Out:
# {'name': 'prash',
#  'email': 'sub',
#  'address': ['XYZ', 'accc', 'sss'],
#  'designation': ['Data Scientist', 'Devloper', 'Data Analyst']}

# %%
pd.DataFrame(d1)
# Out:
#     name email address     designation
# 0  prash   sub     XYZ  Data Scientist
# 1  prash   sub    accc        Devloper
# 2  prash   sub     sss    Data Analyst

# %%
d1 = """
{
  "id": 12,
  "title": "Brown Perfume",
  "description": "Royal_Mirage Sport Brown Perfu...",
  "price": 40,
  "discountPercentage": 15.66,
  "rating": 4,
  "stock": 52,
  "brand": "Royal_Mirage",
  "category": "fragrances",
  "thumbnail": "https://i.dummyjson.com/data/products/12/thumbnail.jpg",
  "images": [
    "https://i.dummyjson.com/data/products/12/1.jpg",
    "https://i.dummyjson.com/data/products/12/2.jpg",
    "https://i.dummyjson.com/data/products/12/3.png",
    "https://i.dummyjson.com/data/products/12/4.jpg",
    "https://i.dummyjson.com/data/products/12/thumbnail.jpg"
  ]
}"""

d1=json.loads(d1)
pd.DataFrame(d1)
# Out:
#    id          title                        description  price  \
# 0  12  Brown Perfume  Royal_Mirage Sport Brown Perfu...     40
# 1  12  Brown Perfume  Royal_Mirage Sport Brown Perfu...     40
# 2  12  Brown Perfume  Royal_Mirage Sport Brown Perfu...     40
# 3  12  Brown Perfume  Royal_Mirage Sport Brown Perfu...     40
# 4  12  Brown Perfume  Royal_Mirage Sport Brown Perfu...     40
#
#    discountPercentage  rating  stock         brand    category  \
# 0               15.66       4     52  Royal_Mirage  fragrances
# 1               15.66       4     52  Royal_Mirage  fragrances
# 2               15.66       4     52  Royal_Mirage  fragrances
# 3               15.66       4     52  Royal_Mirage  fragrances
# 4               15.66       4     52  Royal_Mirage  fragrances
#
#                                            thumbnail  \
# 0  https://i.dummyjson.com/data/products/12/thumb...
# 1  https://i.dummyjson.com/data/products/12/thumb...
# 2  https://i.dummyjson.com/data/products/12/thumb...
# 3  https://i.dummyjson.com/data/products/12/thumb...
# 4  https://i.dummyjson.com/data/products/12/thumb...
#
#                                               images
# 0     https://i.dummyjson.com/data/products/12/1.jpg
# 1     https://i.dummyjson.com/data/products/12/2.jpg
# 2     https://i.dummyjson.com/data/products/12/3.png
# 3     https://i.dummyjson.com/data/products/12/4.jpg
# 4  https://i.dummyjson.com/data/products/12/thumb...

# %%
v1 = """{"comments":[{"id":1,"body":"This is some awesome thinking!","postId":100,"user":{"id":63,"username":"eburras1q"}},{"id":2,"body":"What terrific math skills you’re showing!","postId":27,"user":{"id":71,"username":"omarsland1y"}},{"id":3,"body":"You are an amazing writer!","postId":61,"user":{"id":29,"username":"jissetts"}},{"id":4,"body":"Wow! You have improved so much!","postId":8,"user":{"id":19,"username":"bleveragei"}},{"id":5,"body":"Nice idea!","postId":62,"user":{"id":70,"username":"cmasurel1x"}},{"id":6,"body":"You are showing excellent understanding!","postId":19,"user":{"id":97,"username":"cdavydochkin2o"}},{"id":7,"body":"This is clear, concise, and complete!","postId":47,"user":{"id":22,"username":"froachel"}},{"id":8,"body":"What a powerful argument!","postId":47,"user":{"id":82,"username":"kogilvy29"}},{"id":9,"body":"I knew you could do it!","postId":64,"user":{"id":31,"username":"smargiottau"}},{"id":10,"body":"Wonderful ideas!","postId":4,"user":{"id":35,"username":"mbrooksbanky"}},{"id":11,"body":"It was a pleasure to grade this!","postId":2,"user":{"id":68,"username":"rstrettle1v"}},{"id":12,"body":"Keep up the incredible work!","postId":50,"user":{"id":77,"username":"rkingswood24"}},{"id":13,"body":"My goodness, how impressive!","postId":37,"user":{"id":28,"username":"xisherwoodr"}},{"id":14,"body":"You’re showing inventive ideas!","postId":30,"user":{"id":57,"username":"bpickering1k"}},{"id":15,"body":"You’ve shown so much growth!","postId":44,"user":{"id":76,"username":"cgaber23"}},{"id":16,"body":"Interesting thoughts!","postId":71,"user":{"id":100,"username":"pcumbes2r"}},{"id":17,"body":"I love your neat work!","postId":68,"user":{"id":37,"username":"nwytchard10"}},{"id":18,"body":"Doesn’t it feel good to do such great work?","postId":41,"user":{"id":31,"username":"smargiottau"}},{"id":19,"body":"First-rate work!","postId":75,"user":{"id":60,"username":"dlambarth1n"}},{"id":20,"body":"This is fascinating information!","postId":48,"user":{"id":17,"username":"vcholdcroftg"}},{"id":21,"body":"You inspire me!","postId":29,"user":{"id":5,"username":"kmeus4"}},{"id":22,"body":"This is right on target!","postId":18,"user":{"id":31,"username":"smargiottau"}},{"id":23,"body":"What an astounding observation!","postId":73,"user":{"id":14,"username":"mturleyd"}},{"id":24,"body":"This is very well thought out!","postId":32,"user":{"id":16,"username":"dpierrof"}},{"id":25,"body":"I can tell you’ve been practicing!","postId":44,"user":{"id":78,"username":"dbuist25"}},{"id":26,"body":"You’ve come a long way!","postId":70,"user":{"id":82,"username":"kogilvy29"}},{"id":27,"body":"I can tell you’ve been paying attention!","postId":60,"user":{"id":74,"username":"ahinckes21"}},{"id":28,"body":"Reading this made my day!","postId":85,"user":{"id":85,"username":"kpondjones2c"}},{"id":29,"body":"This is very perceptive!","postId":13,"user":{"id":30,"username":"kdulyt"}},{"id":30,"body":"What an accomplishment!","postId":23,"user":{"id":36,"username":"dalmondz"}}],"total":340,"skip":0,"limit":30}"""
v1 = json.loads(v1)

v1 = pd.DataFrame(v1)
v1
# Out:
#                                              comments  total  skip  limit
# 0   {'id': 1, 'body': 'This is some awesome thinki...    340     0     30
# 1   {'id': 2, 'body': 'What terrific math skills y...    340     0     30
# 2   {'id': 3, 'body': 'You are an amazing writer!'...    340     0     30
# 3   {'id': 4, 'body': 'Wow! You have improved so m...    340     0     30
# 4   {'id': 5, 'body': 'Nice idea!', 'postId': 62, ...    340     0     30
# 5   {'id': 6, 'body': 'You are showing excellent u...    340     0     30
# 6   {'id': 7, 'body': 'This is clear, concise, and...    340     0     30
# 7   {'id': 8, 'body': 'What a powerful argument!',...    340     0     30
# 8   {'id': 9, 'body': 'I knew you could do it!', '...    340     0     30
# 9   {'id': 10, 'body': 'Wonderful ideas!', 'postId...    340     0     30
# 10  {'id': 11, 'body': 'It was a pleasure to grade...    340     0     30
# 11  {'id': 12, 'body': 'Keep up the incredible wor...    340     0     30
# 12  {'id': 13, 'body': 'My goodness, how impressiv...    340     0     30
# 13  {'id': 14, 'body': 'You’re showing inventive i...    340     0     30
# 14  {'id': 15, 'body': 'You’ve shown so much growt...    340     0     30
# 15  {'id': 16, 'body': 'Interesting thoughts!', 'p...    340     0     30
# 16  {'id': 17, 'body': 'I love your neat work!', '...    340     0     30
# 17  {'id': 18, 'body': 'Doesn’t it feel good to do...    340     0     30
# 18  {'id': 19, 'body': 'First-rate work!', 'postId...    340     0     30
# 19  {'id': 20, 'body': 'This is fascinating inform...    340     0     30
# 20  {'id': 21, 'body': 'You inspire me!', 'postId'...    340     0     30
# 21  {'id': 22, 'body': 'This is right on target!',...    340     0     30
# 22  {'id': 23, 'body': 'What an astounding observa...    340     0     30
# 23  {'id': 24, 'body': 'This is very well thought ...    340     0     30
# 24  {'id': 25, 'body': 'I can tell you’ve been pra...    340     0     30
# 25  {'id': 26, 'body': 'You’ve come a long way!', ...    340     0     30
# 26  {'id': 27, 'body': 'I can tell you’ve been pay...    340     0     30
# 27  {'id': 28, 'body': 'Reading this made my day!'...    340     0     30
# 28  {'id': 29, 'body': 'This is very perceptive!',...    340     0     30
# 29  {'id': 30, 'body': 'What an accomplishment!', ...    340     0     30

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"
# pd.read_json(url)
import requests
val=requests.get(url)
data = val.json()
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51108',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51108/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51108/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51108/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/51108',
#   'id': 1566385076,
#   'node_id': 'I_kwDOAA0YD85dXSO0',
#   'number': 51108,
#   'title': 'ENH: hash_pandas_object hook for interface?',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-02-01T16:04:24Z',
#   'updated_at': '2023-02-01T16:04:24Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': "### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nNA\n```\n\n\n### Issue Description\n\nATM hash_pandas_object uses _values_for_factorize, which in principle shouldn't be used outside of EA.factorize.\r\n\r\nxref #48964.\r\n\r\nAFAIK hash_pandas_object isn't used very much, so this isn't all that big of a deal.\n\n### Expected Behavior\n\nNA\n\n### Installed Versions\n\n<details>\r\n\r\nReplace this line with the output of pd.show_versions()\r\n\r\n</details>\r\n",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51108/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51108/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51107',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51107/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51107/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51107/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/51107',
#   'id': 1566031715,
#   'node_id': 'PR_kwDOAA0YD85JARLz',
#   'number': 51107,
#   'title': 'DOC: clean up internals.rst',
#   'user': {'login': 'topper-123',
#    'id': 26364415,
#    'node_id': 'MDQ6VXNlcjI2MzY0NDE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26364415?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/topper-123',
#    'html_url': 'https://github.com/topper-123',
#    'followers_url': 'https://api.github.com/users/topper-123/followers',
#    'following_url': 'https://api.github.com/users/topper-123/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/topper-123/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/topper-123/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/topper-123/subscriptions',
#    'organizations_url': 'https://api.github.com/users/topper-123/orgs',
#    'repos_url': 'https://api.github.com/users/topper-123/repos',
#    'events_url': 'https://api.github.com/users/topper-123/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/topper-123/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-02-01T12:31:30Z',
#   'updated_at': '2023-02-01T12:33:11Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/51107',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/51107',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/51107.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/51107.patch',
#    'merged_at': None},
#   'body': 'Add links to classes etc.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51107/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51107/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51102',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51102/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51102/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51102/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/51102',
#   'id': 1565372826,
#   'node_id': 'PR_kwDOAA0YD85I-Cqj',
#   'number': 51102,
#   'title': "REF: GroupBy.ops don't depend on mutation status",
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-02-01T03:37:10Z',
#   'updated_at': '2023-02-01T15:32:11Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/51102',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/51102',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/51102.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/51102.patch',
#    'merged_at': None},
#   'body': "`self.mutated` is only used in one place (see one-line edit in first commit) and removing that doesn't break anything.  Conceivably could change some behavior but until we have an example I don't think it is even worth documenting as an API change.\r\n\r\nMight be leftover from the old libreduction path?\r\n\r\ncc @jreback for the deep cut into the history",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51102/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51102/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51101',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51101/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51101/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51101/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/51101',
#   'id': 1565265213,
#   'node_id': 'I_kwDOAA0YD85dTA09',
#   'number': 51101,
#   'title': 'DEPR: float/int(Series[single_element])?',
#   'user': {'login': 'mroeschke',
#    'id': 10647082,
#    'node_id': 'MDQ6VXNlcjEwNjQ3MDgy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/10647082?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mroeschke',
#    'html_url': 'https://github.com/mroeschke',
#    'followers_url': 'https://api.github.com/users/mroeschke/followers',
#    'following_url': 'https://api.github.com/users/mroeschke/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 87485152,
#     'node_id': 'MDU6TGFiZWw4NzQ4NTE1Mg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Deprecate',
#     'name': 'Deprecate',
#     'color': '5319e7',
#     'default': False,
#     'description': 'Functionality to remove in pandas'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2023-02-01T01:30:48Z',
#   'updated_at': '2023-02-01T15:46:27Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': "```\r\nIn [1]: float(pd.Series([1]))\r\nOut[1]: 1.0\r\n\r\nIn [2]: int(pd.Series([1]))\r\nOut[2]: 1\r\n```\r\n\r\nRaises a `TypeError` if there's more than one element, but not sure the exact use case for the single element case. `int(ser.iloc[0])` should probably be preferred.",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51101/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51101/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51099',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51099/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51099/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51099/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/51099',
#   'id': 1565195149,
#   'node_id': 'I_kwDOAA0YD85dSvuN',
#   'number': 51099,
#   'title': 'BUG: apply/agg with dictlike and non-unique columns',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 697792067,
#     'node_id': 'MDU6TGFiZWw2OTc3OTIwNjc=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Apply',
#     'name': 'Apply',
#     'color': 'fbca04',
#     'default': False,
#     'description': 'Apply, Aggregate, Transform'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2023-02-01T00:19:44Z',
#   'updated_at': '2023-02-01T04:17:42Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'body': '```python\r\ndf = pd.DataFrame(\r\n    {"A": [None, 2, 3], "B": [1.0, np.nan, 3.0], "C": ["foo", None, "bar"]}\r\n)\r\ndf.columns = ["A", "A", "C"]\r\n\r\nresult = df.agg({"A": "count"})  # same with \'apply\' instead of \'agg\'\r\nexpected = df["A"].count()\r\ntm.assert_series_equal(result, expected)\r\n```\r\n\r\nThis goes through Apply.agg_dict_like, which does\r\n\r\n```\r\nresults = {\r\n    key: obj._gotitem(key, ndim=1).agg(how) for key, how in arg.items()\r\n}\r\n```\r\n\r\nWhich operates column-by-column on the relevant columns _if_ columns are unique.  But with a repeated column obj._gotitem returns a DataFrame, so the .agg returns a DataFrame.\r\n\r\nNo existing test cases get here with non-unique columns, or with Resample/GroupBy objects whose underlying object has non-unique columns.\r\n\r\ncc @rhshadrach \r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51099/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51099/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51098',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51098/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51098/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51098/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/51098',
#   'id': 1565093489,
#   'node_id': 'PR_kwDOAA0YD85I9GnM',
#   'number': 51098,
#   'title': 'DEPR: Remove NumericIndex from pandas/_testing/',
#   'user': {'login': 'topper-123',
#    'id': 26364415,
#    'node_id': 'MDQ6VXNlcjI2MzY0NDE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26364415?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/topper-123',
#    'html_url': 'https://github.com/topper-123',
#    'followers_url': 'https://api.github.com/users/topper-123/followers',
#    'following_url': 'https://api.github.com/users/topper-123/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/topper-123/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/topper-123/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/topper-123/subscriptions',
#    'organizations_url': 'https://api.github.com/users/topper-123/orgs',
#    'repos_url': 'https://api.github.com/users/topper-123/repos',
#    'events_url': 'https://api.github.com/users/topper-123/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/topper-123/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-31T22:30:24Z',
#   'updated_at': '2023-02-01T13:41:49Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/51098',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/51098',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/51098.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/51098.patch',
#    'merged_at': None},
#   'body': 'Removes `NumericIndex` from `pandas._testing`.\r\n\r\nA decision has to be made how `assert_index_equal` should interpret equivalence between an index and a `RangeIndex`. IMO two indexes should be equivalent if they\'re both return true for one of the two tests below:\r\n1.  isinstance(index, RangeIndex) is True, or\r\n2. (type(index) is Index and index.dtype == "int64") is True\r\n\r\nThe first is easy to agree on, but notice that the second means that an `Index` subclass with int64 dtype will not be equivalent to a `RangeIndex`. My thinking is that if the user subclasses `Index`, then subclass instances shouldn\'t be equivalent to `RangeIndex`, even if it has a int64 dtype.\r\n\r\nAlso, int32/int16/int8 indexes won\'t be equivalent to `RangeIndex` in this implementation.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51098/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51098/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51097',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51097/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51097/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51097/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/51097',
#   'id': 1565086888,
#   'node_id': 'I_kwDOAA0YD85dSVSo',
#   'number': 51097,
#   'title': 'DOC: GroupBy.rolling() not in docs',
#   'user': {'login': 'davidgilbertson',
#    'id': 4443482,
#    'node_id': 'MDQ6VXNlcjQ0NDM0ODI=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4443482?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/davidgilbertson',
#    'html_url': 'https://github.com/davidgilbertson',
#    'followers_url': 'https://api.github.com/users/davidgilbertson/followers',
#    'following_url': 'https://api.github.com/users/davidgilbertson/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/davidgilbertson/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/davidgilbertson/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/davidgilbertson/subscriptions',
#    'organizations_url': 'https://api.github.com/users/davidgilbertson/orgs',
#    'repos_url': 'https://api.github.com/users/davidgilbertson/repos',
#    'events_url': 'https://api.github.com/users/davidgilbertson/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/davidgilbertson/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-31T22:23:16Z',
#   'updated_at': '2023-01-31T22:23:16Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': "### Pandas version checks\n\n- [X] I have checked that the issue still exists on the latest versions of the docs on `main` [here](https://pandas.pydata.org/docs/dev/)\n\n\n### Location of the documentation\n\nhttps://pandas.pydata.org/docs/reference/groupby.html\r\nhttps://pandas.pydata.org/docs/dev/reference/groupby.html\n\n### Documentation problem\n\nIn the source code for `GroupBy` I see [rolling](https://github.com/pandas-dev/pandas/blob/main/pandas/core/groupby/groupby.py#L2781) and `ewm` and `expanding` but I don't see these in the docs.\r\n\r\nI can't work out if they've been deprecated, or are very new, or if there's a bug in the documentation creation.\n\n### Suggested fix for documentation\n\nDepending on why they're not in the docs, either an update to the docstring to mention that these aren't part of the official API (and why, and what to use instead maybe, or maybe a deprecation warning) or update the docs to include them.",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51097/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51097/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51093',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51093/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51093/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51093/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/51093',
#   'id': 1564837551,
#   'node_id': 'I_kwDOAA0YD85dRYav',
#   'number': 51093,
#   'title': 'ENH: Native conditionals (if, elif, elif, else like np.select)',
#   'user': {'login': 'mattharrison',
#    'id': 119405,
#    'node_id': 'MDQ6VXNlcjExOTQwNQ==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/119405?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mattharrison',
#    'html_url': 'https://github.com/mattharrison',
#    'followers_url': 'https://api.github.com/users/mattharrison/followers',
#    'following_url': 'https://api.github.com/users/mattharrison/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/mattharrison/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mattharrison/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mattharrison/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mattharrison/orgs',
#    'repos_url': 'https://api.github.com/users/mattharrison/repos',
#    'events_url': 'https://api.github.com/users/mattharrison/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mattharrison/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76812,
#     'node_id': 'MDU6TGFiZWw3NjgxMg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Enhancement',
#     'name': 'Enhancement',
#     'color': '4E9A06',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2023-01-31T18:54:09Z',
#   'updated_at': '2023-01-31T20:27:08Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Feature Type\n\n- [X] Adding new functionality to pandas\n\n- [ ] Changing existing functionality in pandas\n\n- [ ] Removing existing functionality in pandas\n\n\n### Problem Description\n\nIf statements are a pain in Pandas. The `.where` method is confusing, and most folks resort to writing a function and using `.apply` to use old-school Python style conditionals.\r\n\r\nAlso, I\'m not a fan of using sequences of `.loc` assignment because it breaks chaining.\r\n\r\nI\'ve resorted to using `np.select`. It would be great to have this as native functionality.\r\n\r\nConsider calculating On-balance Volume (OBV)\r\n![Screen Shot 2023-01-31 at 11 41 00 AM](https://user-images.githubusercontent.com/119405/215852883-a9507530-8123-4149-b3a8-370667098ff3.png)\r\n\r\nMany resort to this:\r\n\r\n```\r\n# naive\r\n\r\ndef calc_obv(df):\r\n    df = df.copy()\r\n    df["OBV"] = 0.0\r\n\r\n    # Loop through the data and calculate OBV\r\n    for i in range(1, len(df)):\r\n        if df["Close"][i] > df["Close"][i - 1]:\r\n            df["OBV"][i] = df["OBV"][i - 1] + df["Volume"][i]\r\n        elif df["Close"][i] < df["Close"][i - 1]:\r\n            df["OBV"][i] = df["OBV"][i - 1] - df["Volume"][i]\r\n        else:\r\n            df["OBV"][i] = df["OBV"][i - 1]  \r\n    return df\r\n\r\ncalc_obv(aapl)\r\n```\r\n\r\nHere\'s my attempt with `.where`:\r\n\r\n```\r\n# This is painful\r\n(aapl\r\n .assign(close_prev=aapl.Close.shift(1),\r\n         vol=0,\r\n         obv=lambda adf: adf.vol.where(cond=adf.Close == adf.close_prev, \r\n                                       other=adf.Volume.where(cond=adf.Close > adf.close_prev, \r\n                                                  other=-adf.Volume.where(cond=adf.Close < adf.close_prev, other=0)\r\n                                        )).cumsum()\r\n        )\r\n)\r\n```\r\n\r\nHere\'s my `np.select` version:\r\n\r\n```\r\n(aapl\r\n .assign(vol=np.select([aapl.Close > aapl.Close.shift(1), \r\n                        aapl.Close == aapl.Close.shift(1), \r\n                        aapl.Close < aapl.Close.shift(1)],\r\n                       [aapl.Volume, 0, -aapl.Volume]),\r\n         obv=lambda df_:df_.vol.cumsum(),\r\n        )\r\n)\r\n\r\n```\n\n### Feature Description\n\nNew method (adapted from NumPy):\r\n\r\n```\r\ndef select(self, condlist, choicelist, default=0):\r\n    """\r\n    Return an array drawn from elements in choicelist, depending on conditions.\r\n\r\n    Parameters\r\n    ----------\r\n    condlist : list of bool ndarrays\r\n        The list of conditions which determine from which array in `choicelist`\r\n        the output elements are taken. When multiple conditions are satisfied,\r\n        the first one encountered in `condlist` is used.\r\n    choicelist : list of ndarrays\r\n        The list of arrays from which the output elements are taken. It has\r\n        to be of the same length as `condlist`.\r\n    default : scalar, optional\r\n        The element inserted in `output` when all conditions evaluate to False.\r\n\r\n    Returns\r\n    -------\r\n    output : Dataframe/Series\r\n        The output at position m is the m-th element of the array in\r\n        `choicelist` where the m-th element of the corresponding array in\r\n        `condlist` is True.\r\n    """\r\n    return np.select(condlist, choicelist, default)\r\n```\n\n### Alternative Solutions\n\n* `np.select` - https://numpy.org/doc/stable/reference/generated/numpy.select.html\r\n\r\n* Polars `when` - https://pola-rs.github.io/polars-book/user-guide/dsl/expressions.html#binary-functions-and-modification\n\n### Additional Context\n\n_No response_',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51093/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51093/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51092',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51092/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51092/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51092/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/51092',
#   'id': 1564801083,
#   'node_id': 'PR_kwDOAA0YD85I8IlT',
#   'number': 51092,
#   'title': 'API: integer values and non-nano dtype',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 3713792788,
#     'node_id': 'LA_kwDOAA0YD87dW_sU',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Non-Nano',
#     'name': 'Non-Nano',
#     'color': '006b75',
#     'default': False,
#     'description': 'datetime64/timedelta64 with non-nanosecond resolution'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-31T18:21:04Z',
#   'updated_at': '2023-02-01T15:32:41Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/51092',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/51092',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/51092.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/51092.patch',
#    'merged_at': None},
#   'body': "I'm open to suggestions for a better wording on the whatsnew.\r\n\r\nNote this handles all-int cases but not mixed-int.\r\n\r\ntimedelta64 analogue coming up.",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51092/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51092/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51090',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51090/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51090/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51090/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/51090',
#   'id': 1564740640,
#   'node_id': 'PR_kwDOAA0YD85I77wB',
#   'number': 51090,
#   'title': 'PERF: avoid copy in _obj_with_exclusions, _selected_obj',
#   'user': {'login': 'jbrockmendel',
#    'id': 8078968,
#    'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/jbrockmendel',
#    'html_url': 'https://github.com/jbrockmendel',
#    'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#    'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#    'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#    'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 233160,
#     'node_id': 'MDU6TGFiZWwyMzMxNjA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Groupby',
#     'name': 'Groupby',
#     'color': '729FCF',
#     'default': False,
#     'description': None},
#    {'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/42',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/42',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/42/labels',
#    'id': 1945020,
#    'node_id': 'MDk6TWlsZXN0b25lMTk0NTAyMA==',
#    'number': 42,
#    'title': '2.0',
#    'description': '',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 53,
#    'closed_issues': 1210,
#    'state': 'open',
#    'created_at': '2016-08-16T13:21:24Z',
#    'updated_at': '2023-02-01T15:43:13Z',
#    'due_on': '2023-01-31T08:00:00Z',
#    'closed_at': None},
#   'comments': 2,
#   'created_at': '2023-01-31T17:36:26Z',
#   'updated_at': '2023-02-01T15:31:45Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/51090',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/51090',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/51090.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/51090.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\ncc @rhshadrach \r\n\r\n```\r\nimport pandas as pd\r\nimport numpy as np\r\nimport psutil\r\nproc = psutil.Process()\r\n\r\nnp.random.seed(456123)\r\ndf = pd.DataFrame(\r\n    np.random.randn(10_000_000, 5),\r\n    columns=["A", "B", "C", "D", "E"],\r\n)\r\n\r\ngrps = np.arange(10).repeat(1_000_000)\r\ngb = df.groupby(grps)\r\n\r\ngb2 = gb[["C"]]\r\n\r\nIn [3]: np.shares_memory(gb2._obj_with_exclusions["C"], df["C"])\r\nTrue   # <- PR\r\nFalse  # <- main\r\n\r\nIn [5]: proc.memory_info()\r\nOut[5]: pmem(rss=658894848, vms=36076212224, pfaults=169250, pageins=0)  <- main\r\nOut[5]: pmem(rss=578924544, vms=35993063424, pfaults=149692, pageins=0)  <- PR\r\n```',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51090/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51090/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51088',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51088/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51088/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51088/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/51088',
#   'id': 1564726757,
#   'node_id': 'PR_kwDOAA0YD85I749v',
#   'number': 51088,
#   'title': 'TEST: join df with categorical multiIndex',
#   'user': {'login': 'natmokval',
#    'id': 91160475,
#    'node_id': 'MDQ6VXNlcjkxMTYwNDc1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/91160475?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/natmokval',
#    'html_url': 'https://github.com/natmokval',
#    'followers_url': 'https://api.github.com/users/natmokval/followers',
#    'following_url': 'https://api.github.com/users/natmokval/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/natmokval/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/natmokval/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/natmokval/subscriptions',
#    'organizations_url': 'https://api.github.com/users/natmokval/orgs',
#    'repos_url': 'https://api.github.com/users/natmokval/repos',
#    'events_url': 'https://api.github.com/users/natmokval/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/natmokval/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 127685,
#     'node_id': 'MDU6TGFiZWwxMjc2ODU=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Testing',
#     'name': 'Testing',
#     'color': 'C4A000',
#     'default': False,
#     'description': 'pandas testing functions or related to the test suite'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-31T17:26:32Z',
#   'updated_at': '2023-02-01T14:49:14Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': True,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/51088',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/51088',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/51088.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/51088.patch',
#    'merged_at': None},
#   'body': '- [x] closes #50906\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n\r\nAdd test to check index dtype after joining DataFrames with categorical multiIndex.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51088/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51088/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51087',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51087/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51087/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51087/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/51087',
#   'id': 1564704727,
#   'node_id': 'PR_kwDOAA0YD85I70Lx',
#   'number': 51087,
#   'title': "BUG: can't round-trip non-nano Timestamp",
#   'user': {'login': 'MarcoGorelli',
#    'id': 33491632,
#    'node_id': 'MDQ6VXNlcjMzNDkxNjMy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/33491632?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MarcoGorelli',
#    'html_url': 'https://github.com/MarcoGorelli',
#    'followers_url': 'https://api.github.com/users/MarcoGorelli/followers',
#    'following_url': 'https://api.github.com/users/MarcoGorelli/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/MarcoGorelli/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/MarcoGorelli/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/MarcoGorelli/subscriptions',
#    'organizations_url': 'https://api.github.com/users/MarcoGorelli/orgs',
#    'repos_url': 'https://api.github.com/users/MarcoGorelli/repos',
#    'events_url': 'https://api.github.com/users/MarcoGorelli/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/MarcoGorelli/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 3713792788,
#     'node_id': 'LA_kwDOAA0YD87dW_sU',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Non-Nano',
#     'name': 'Non-Nano',
#     'color': '006b75',
#     'default': False,
#     'description': 'datetime64/timedelta64 with non-nanosecond resolution'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-31T17:10:36Z',
#   'updated_at': '2023-02-01T15:44:59Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/51087',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/51087',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/51087.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/51087.patch',
#    'merged_at': None},
#   'body': "- [ ] xref #51060 (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nThis should fix the interger case, but not the float one, so let's still keep the issue open for now",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51087/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51087/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51086',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51086/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51086/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51086/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/51086',
#   'id': 1564629353,
#   'node_id': 'I_kwDOAA0YD85dQllp',
#   'number': 51086,
#   'title': 'BUG: Cannot connect to sql',
#   'user': {'login': 'Edimo05',
#    'id': 94873872,
#    'node_id': 'U_kgDOBaepEA',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/94873872?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Edimo05',
#    'html_url': 'https://github.com/Edimo05',
#    'followers_url': 'https://api.github.com/users/Edimo05/followers',
#    'following_url': 'https://api.github.com/users/Edimo05/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Edimo05/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Edimo05/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Edimo05/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Edimo05/orgs',
#    'repos_url': 'https://api.github.com/users/Edimo05/repos',
#    'events_url': 'https://api.github.com/users/Edimo05/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Edimo05/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
# ...
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-30T09:46:32Z',
#   'updated_at': '2023-01-30T09:46:32Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\n\r\ndf1 = pd.DataFrame({("n1", "q1"): [1], ("n2", "q1"): [2]}, dtype="float32")\r\nprint(df1.stack(level=0).dtypes)  # q1 is float32\r\n\r\ndf2 = pd.DataFrame({("n1", "q1"): [1], ("n2", "q2"): [2]}, dtype="float32")\r\nprint(df2.stack(level=0).dtypes)  # q1 and q2 are float64\n```\n\n\n### Issue Description\n\nIn some cases, `DataFrame.stack` will "change" the dtype of the resulting columns, in my case from `float32` to `float64`.\n\n### Expected Behavior\n\nI would expect `DataFrame.stack()` to return a `float32` DataFrame if the input DataFrame was also `float32`.\n\n### Installed Versions\n\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 2e218d10984e9919f0296931d92ea851c6a6faf5\r\npython           : 3.8.9.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.4.0-104-generic\r\nVersion          : #118-Ubuntu SMP Wed Mar 2 19:02:41 UTC 2022\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : C.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.5.3\r\nnumpy            : 1.23.3\r\npytz             : 2022.1\r\ndateutil         : 2.8.2\r\nsetuptools       : 67.0.0\r\npip              : 22.3.1\r\nCython           : None\r\npytest           : 7.2.0\r\nhypothesis       : None\r\nsphinx           : 5.3.0\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : 2.9.3\r\njinja2           : 3.1.2\r\nIPython          : 8.7.0\r\npandas_datareader: None\r\nbs4              : 4.11.1\r\nbottleneck       : None\r\nbrotli           : None\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib       : None\r\nnumba            : None\r\nnumexpr          : 2.8.1\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : 10.0.1\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.8.1\r\nsnappy           : None\r\nsqlalchemy       : None\r\ntables           : 3.7.0\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nzstandard        : None\r\ntzdata           : None\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51059/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51059/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51057',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51057/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51057/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51057/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/51057',
#   'id': 1561457647,
#   'node_id': 'PR_kwDOAA0YD85Iw2-v',
#   'number': 51057,
#   'title': 'BUG: Series(category).replace to maintain order of categories',
#   'user': {'login': 'lukemanley',
#    'id': 8519523,
#    'node_id': 'MDQ6VXNlcjg1MTk1MjM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8519523?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lukemanley',
#    'html_url': 'https://github.com/lukemanley',
#    'followers_url': 'https://api.github.com/users/lukemanley/followers',
#    'following_url': 'https://api.github.com/users/lukemanley/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lukemanley/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lukemanley/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lukemanley/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lukemanley/orgs',
#    'repos_url': 'https://api.github.com/users/lukemanley/repos',
#    'events_url': 'https://api.github.com/users/lukemanley/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lukemanley/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 78527356,
#     'node_id': 'MDU6TGFiZWw3ODUyNzM1Ng==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Categorical',
#     'name': 'Categorical',
#     'color': 'e11d21',
#     'default': False,
#     'description': 'Categorical Data Type'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-29T21:08:44Z',
#   'updated_at': '2023-01-31T02:26:45Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/51057',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/51057',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/51057.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/51057.patch',
#    'merged_at': None},
#   'body': '- [x] closes #51016\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n\r\nNo whatsnew as this is a regression on main only.\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51057/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51057/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51056',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51056/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51056/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51056/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/51056',
#   'id': 1561443318,
#   'node_id': 'PR_kwDOAA0YD85Iw0SL',
#   'number': 51056,
#   'title': 'BUG: Series.tolist to return None in place of pd.NA',
#   'user': {'login': 'lukemanley',
#    'id': 8519523,
#    'node_id': 'MDQ6VXNlcjg1MTk1MjM=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8519523?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lukemanley',
#    'html_url': 'https://github.com/lukemanley',
#    'followers_url': 'https://api.github.com/users/lukemanley/followers',
#    'following_url': 'https://api.github.com/users/lukemanley/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lukemanley/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/lukemanley/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lukemanley/subscriptions',
#    'organizations_url': 'https://api.github.com/users/lukemanley/orgs',
#    'repos_url': 'https://api.github.com/users/lukemanley/repos',
#    'events_url': 'https://api.github.com/users/lukemanley/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/lukemanley/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 2822342,
#     'node_id': 'MDU6TGFiZWwyODIyMzQy',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Missing-data',
#     'name': 'Missing-data',
#     'color': 'd7e102',
#     'default': False,
#     'description': 'np.nan, pd.NaT, pd.NA, dropna, isnull, interpolate'},
#    {'id': 31404521,
#     'node_id': 'MDU6TGFiZWwzMTQwNDUyMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Dtype%20Conversions',
#     'name': 'Dtype Conversions',
#     'color': 'e102d8',
#     'default': False,
#     'description': 'Unexpected or buggy dtype conversions'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-29T20:16:10Z',
#   'updated_at': '2023-01-30T10:04:03Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/51056',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/51056',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/51056.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/51056.patch',
#    'merged_at': None},
#   'body': '- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nAs discussed here: https://github.com/pandas-dev/pandas/issues/29738#issuecomment-1407693166\r\n\r\nOffering this up as a potential solution to make `Series.tolist` return `None` (python native types) in place of `pd.NA`. This would make `Series.tolist` consistent with `Series.to_dict` which at the moment differ:\r\n\r\n```\r\nIn [1]: import pandas as pd\r\n\r\nIn [2]: ser = pd.Series([1, pd.NA], dtype="Int64")\r\n\r\nIn [3]: ser.to_dict()\r\nOut[3]: {0: 1, 1: None}\r\n\r\nIn [4]: ser.tolist()\r\nOut[4]: [1, <NA>]\r\n```\r\n\r\nI don\'t think this fully closes #29738 as there may still be an open question about `__iter__`. ',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51056/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51056/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51054',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51054/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51054/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51054/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/51054',
#   'id': 1561263471,
#   'node_id': 'PR_kwDOAA0YD85IwP8E',
#   'number': 51054,
#   'title': 'PERF: improve performance of infer_dtype',
#   'user': {'login': 'topper-123',
#    'id': 26364415,
#    'node_id': 'MDQ6VXNlcjI2MzY0NDE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26364415?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/topper-123',
#    'html_url': 'https://github.com/topper-123',
#    'followers_url': 'https://api.github.com/users/topper-123/followers',
#    'following_url': 'https://api.github.com/users/topper-123/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/topper-123/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/topper-123/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/topper-123/subscriptions',
#    'organizations_url': 'https://api.github.com/users/topper-123/orgs',
#    'repos_url': 'https://api.github.com/users/topper-123/repos',
#    'events_url': 'https://api.github.com/users/topper-123/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/topper-123/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 8935311,
#     'node_id': 'MDU6TGFiZWw4OTM1MzEx',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Performance',
#     'name': 'Performance',
#     'color': 'a10c02',
#     'default': False,
#     'description': 'Memory or execution speed performance'},
#    {'id': 31404521,
#     'node_id': 'MDU6TGFiZWwzMTQwNDUyMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Dtype%20Conversions',
#     'name': 'Dtype Conversions',
#     'color': 'e102d8',
#     'default': False,
#     'description': 'Unexpected or buggy dtype conversions'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-01-29T12:20:05Z',
#   'updated_at': '2023-01-30T18:56:46Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/51054',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/51054',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/51054.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/51054.patch',
#    'merged_at': None},
#   'body': 'Improves performance of `api.types.infer_dtype`:\r\n\r\n```python\r\n>>> import numpy as np\r\n>>> import pandas as pd\r\n>>> from pandas.api.types import infer_dtype\r\n>>>\r\n>>> base_arr = np.arange(10_000_000)\r\n>>> x = np.array(base_arr)\r\n>>> %timeit infer_dtype(x)\r\n596 ns ± 128 ns per loop  # main\r\n146 ns ± 8.73 ns per loop  # this PR\r\n>>> x = pd.Series(base_arr)\r\n>>> %timeit infer_dtype(x)\r\n6.83 µs ± 33.7 ns per loop  # main\r\n583 ns ± 5.4 ns per loop  # this PR\r\n>>> x = pd.Series(base_arr, dtype="Int32")\r\n>>> %timeit infer_dtype(x)\r\n3.92 µs ± 9.9 ns per loop  # main\r\n816 ns ± 4.75 ns per loop  # this PR\r\n>>> x = pd.array(base_arr)\r\n>>> %timeit infer_dtype(x)\r\n310 ns ± 0.704 ns per loop  # main\r\n582 ns ± 4.73 ns per loop  # this PR , a bit slower\r\n```\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51054/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/51054/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
# for i in range(len(data)):
#     print(data[i]['user']['id'])

read_data_url=pd.DataFrame(data,columns=["id","url","repository_url","user"])
read_data_url.head(3)
# Out:
#            id                                                url  \
# 0  1566385076  https://api.github.com/repos/pandas-dev/pandas...
# 1  1566031715  https://api.github.com/repos/pandas-dev/pandas...
# 2  1565372826  https://api.github.com/repos/pandas-dev/pandas...
#
#                                    repository_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas
# 1  https://api.github.com/repos/pandas-dev/pandas
# 2  https://api.github.com/repos/pandas-dev/pandas
#
#                                                 user
# 0  {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 1  {'login': 'topper-123', 'id': 26364415, 'node_...
# 2  {'login': 'jbrockmendel', 'id': 8078968, 'node...

# %%
# read_csv
# read_html 
# read_xlsx
# read_json
# json.normalize

# %%
final_df=pd.json_normalize(data,max_level=1)

# %%
final_df.columns
# Out:
# Index(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url',
#        'html_url', 'id', 'node_id', 'number', 'title', 'labels', 'state',
#        'locked', 'assignee', 'assignees', 'milestone', 'comments',
#        'created_at', 'updated_at', 'closed_at', 'author_association',
#        'active_lock_reason', 'body', 'timeline_url',
#        'performed_via_github_app', 'state_reason', 'user.login', 'user.id',
#        'user.node_id', 'user.avatar_url', 'user.gravatar_id', 'user.url',
#        'user.html_url', 'user.followers_url', 'user.following_url',
#        'user.gists_url', 'user.starred_url', 'user.subscriptions_url',
#        'user.organizations_url', 'user.repos_url', 'user.events_url',
#        'user.received_events_url', 'user.type', 'user.site_admin',
#        'reactions.url', 'reactions.total_count', 'reactions.+1',
#        'reactions.-1', 'reactions.laugh', 'reactions.hooray',
#        'reactions.confused', 'reactions.heart', 'reactions.rocket',
#        'reactions.eyes', 'draft', 'pull_request.url', 'pull_request.html_url',
#        'pull_request.diff_url', 'pull_request.patch_url',
#        'pull_request.merged_at', 'milestone.url', 'milestone.html_url',
#        'milestone.labels_url', 'milestone.id', 'milestone.node_id',
#        'milestone.number', 'milestone.title', 'milestone.description',
#        'milestone.creator', 'milestone.open_issues', 'milestone.closed_issues',
#        'milestone.state', 'milestone.created_at', 'milestone.updated_at',
#        'milestone.due_on', 'milestone.closed_at', 'assignee.login',
#        'assignee.id', 'assignee.node_id', 'assignee.avatar_url',
#        'assignee.gravatar_id', 'assignee.url', 'assignee.html_url',
#        'assignee.followers_url', 'assignee.following_url',
#        'assignee.gists_url', 'assignee.starred_url',
#        'assignee.subscriptions_url', 'assignee.organizations_url',
#        'assignee.repos_url', 'assignee.events_url',
#        'assignee.received_events_url', 'assignee.type', 'assignee.site_admin'],
#       dtype='object')
